# %%
# import or install libraries to use

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# !pip install squarify
import squarify

#remove warnings
import warnings
warnings.filterwarnings('ignore')
# Out:
# Requirement already satisfied: squarify in c:\programdata\anaconda3\lib\site-packages (0.4.3)

# %%
# read and display first 3 rows of the data
# display crimes reported are from 01-2021

other_cities = pd.read_csv('C:/Users/User/Downloads/other_cities_df.csv')
other_cities.head(3)
# Out:
#    Unnamed: 0    month            reported by  longitude   latitude  \
# 0           0  2018-01  West Yorkshire Police  -1.388671  53.935321
# 1           1  2018-01  West Yorkshire Police  -1.391328  53.938003
# 2           2  2018-01  West Yorkshire Police  -1.388828  53.936031
#
#                   location  lsoa code lsoa name                 crime type  \
# 0  On or near Coxwold View    1011698     Leeds  Criminal damage and arson
# 1   On or near Supermarket    1011698     Leeds                Shoplifting
# 2  On or near Coxwold Hill    1011698     Leeds              Vehicle crime
#
#                            last outcome category  covid     date  stringency
# 0  Investigation complete; no suspect identified      0  2018-01         0.0
# 1  Investigation complete; no suspect identified      0  2018-01         0.0
# 2  Investigation complete; no suspect identified      0  2018-01         0.0

# %%
# read and display last 3 rows of the data
# displays crimes reported until 09-2021

other_cities.tail(3)
# Out:
#          Unnamed: 0    month                     reported by  longitude  \
# 1220532     1220532  2021-09  Avon and Somerset Constabulary  -2.559442
# 1220533     1220533  2021-09  Avon and Somerset Constabulary  -2.560748
# 1220534     1220534  2021-09  Avon and Somerset Constabulary  -2.559340
#
#           latitude                  location  lsoa code lsoa name  \
# 1220532  51.472717  On or near Apsley Street    1014574   Bristol
# 1220533  51.472315      On or near Glen Park    1014574   Bristol
# 1220534  51.471396  On or near Juniper Court    1014574   Bristol
#
#                            crime type  \
# 1220532  Violence and sexual offences
# 1220533  Violence and sexual offences
# 1220534  Violence and sexual offences
#
#                               last outcome category  covid     date  \
# 1220532                 Unable to prosecute suspect      1  2021-09
# 1220533  Action to be taken by another organisation      1  2021-09
# 1220534                 Unable to prosecute suspect      1  2021-09
#
#          stringency
# 1220532      42.034
# 1220533      42.034
# 1220534      42.034

# %%
# check all data columns

other_cities.columns
# Out:
# Index(['Unnamed: 0', 'month', 'reported by', 'longitude', 'latitude',
#        'location', 'lsoa code', 'lsoa name', 'crime type',
#        'last outcome category', 'covid', 'date', 'stringency'],
#       dtype='object')

# %%
# drop Unnamed column

other_cities.drop('Unnamed: 0', inplace=True, axis=1)

# %%
# display data shape

other_cities.shape
# Out:
# (1220535, 12)

# %%
# display data information 

other_cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220535 entries, 0 to 1220534
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   month                  1220535 non-null  object
#  1   reported by            1220535 non-null  object
#  2   longitude              1220535 non-null  float64
#  3   latitude               1220535 non-null  float64
#  4   location               1220535 non-null  object
#  5   lsoa code              1220535 non-null  int64
#  6   lsoa name              1220535 non-null  object
#  7   crime type             1220535 non-null  object
#  8   last outcome category  1220535 non-null  object
#  9   covid                  1220535 non-null  int64
#  10  date                   1220535 non-null  object
#  11  stringency             1220535 non-null  float64
# dtypes: float64(3), int64(2), object(7)
# memory usage: 111.7+ MB

# %%
# describe the data

other_cities.describe()
# Out:
#           longitude      latitude     lsoa code         covid    stringency
# count  1.220535e+06  1.220535e+06  1.220535e+06  1.220535e+06  1.220535e+06
# mean  -1.988273e+00  5.333139e+01  1.014244e+06  4.088478e-01  2.638383e+01
# std    5.759625e-01  7.865032e-01  8.898407e+03  4.916213e-01  3.310498e+01
# min   -3.002089e+00  5.139996e+01  1.006512e+06  0.000000e+00  0.000000e+00
# 25%   -2.591272e+00  5.338264e+01  1.008098e+06  0.000000e+00  0.000000e+00
# 50%   -1.732999e+00  5.374436e+01  1.011322e+06  0.000000e+00  0.000000e+00
# 75%   -1.527028e+00  5.380211e+01  1.014542e+06  1.000000e+00  6.430310e+01
# max   -1.306890e+00  5.394893e+01  1.033768e+06  1.000000e+00  8.748037e+01

# %%
# check for null values in dataset

other_cities.isna().sum()
# Out:
# month                    0
# reported by              0
# longitude                0
# latitude                 0
# location                 0
# lsoa code                0
# lsoa name                0
# crime type               0
# last outcome category    0
# covid                    0
# date                     0
# stringency               0
# dtype: int64

# %%
# visualise the null values

plt.figure(figsize = (8,7))
sns.heatmap(other_cities.isnull(), yticklabels=False, cbar=False, cmap='viridis')
plt.show()
plt.savefig('Missing Values')

# %%
# export csv

other_cities.to_csv('C:/Users/User/other_cities_df.csv', index=False)

# %%
# read exported data
# display first 3 rows

other_cities = pd.read_csv('C:/Users/User/other_cities_df.csv')
other_cities.head(3)
# Out:
#      month            reported by  longitude   latitude  \
# 0  2018-01  West Yorkshire Police  -1.388671  53.935321
# 1  2018-01  West Yorkshire Police  -1.391328  53.938003
# 2  2018-01  West Yorkshire Police  -1.388828  53.936031
#
#                   location  lsoa code lsoa name                 crime type  \
# 0  On or near Coxwold View    1011698     Leeds  Criminal damage and arson
# 1   On or near Supermarket    1011698     Leeds                Shoplifting
# 2  On or near Coxwold Hill    1011698     Leeds              Vehicle crime
#
#                            last outcome category  covid     date  stringency
# 0  Investigation complete; no suspect identified      0  2018-01         0.0
# 1  Investigation complete; no suspect identified      0  2018-01         0.0
# 2  Investigation complete; no suspect identified      0  2018-01         0.0

# %%
# display top crime types reported

x = other_cities['crime type'].value_counts()
print('Top crimes reported in Leeds, Liverpool, Bradford, Sheffield and Bristol 2018-2021:')
print(x)
# Out:
# Top crimes reported in Leeds, Liverpool, Bradford, Sheffield and Bristol 2018-2021:
# Violence and sexual offences    463991
# Public order                    139385
# Criminal damage and arson       129031
# Other theft                      94682
# Vehicle crime                    92373
# Burglary                         91292
# Shoplifting                      70628
# Drugs                            49485
# Other crime                      28174
# Theft from the person            18043
# Bicycle theft                    16658
# Robbery                          16012
# Possession of weapons            10781
# Name: crime type, dtype: int64

# %%
# display total number of street crimes reported per city 

other_cities['lsoa name'].value_counts()
# Out:
# Leeds        366495
# Bradford     261950
# Liverpool    223188
# Sheffield    194924
# Bristol      173978
# Name: lsoa name, dtype: int64

# %%
# display crime type count in graph

plt.rcParams['figure.figsize'] = (15, 10)
plt.style.use('dark_background')

sns.countplot(other_cities['crime type'], palette = 'gnuplot')

plt.title('Street Crimes Reported in Leeds, Bradford, Liverpool, Sheffield and Bristol 2018-2021', fontweight = 30, fontsize = 20)
plt.xticks(rotation=45)
plt.tight_layout()
plt.grid(False)
plt.show();

# %%
# tree map visualisation of crime types

y = other_cities['crime type'].value_counts()
    
plt.rcParams['figure.figsize'] = (10, 8)
plt.style.use('fivethirtyeight')

color = plt.cm.viridis(np.linspace(0, 1, 15))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color)
plt.title('Tree Map Crime Types', fontsize = 20, color = 'black')

plt.axis('off')
plt.show()

# %%
# display count of crimes per city

plt.rcParams['figure.figsize'] = (20, 10)
plt.style.use('dark_background')

color = plt.cm.viridis(np.linspace(0, 1, 5))
other_cities['lsoa name'].value_counts().head(5).plot.bar(color = color, figsize = (20, 10))

plt.title('Number of Street Crimes Reported per City 2018-2021',fontsize = 20)

plt.xticks(rotation = 45)
plt.grid(False)

plt.show()

# %%
# display top crime locations

plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('dark_background')

color = plt.cm.spring(np.linspace(0, 1, 15))
other_cities['location'].value_counts().head(15).plot.bar(color = color, figsize = (20, 10))

plt.title('Top 15 Crime Spots in Leeds, Bradford, Liverpool, Sheffield and Bristol 2018-2021',fontsize = 20)

plt.xticks(rotation = 45)
plt.grid(b=None)
plt.show()

# %%
# display outcomes of top 15 crimes reported

plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('dark_background')

color = plt.cm.winter(np.linspace(0, 1, 15))
other_cities['last outcome category'].value_counts().head(15).plot.bar(color = color, figsize = (15, 10))

plt.title('Top 15 Crime Outcomes in Leeds, Bradford, Liverpool, Sheffield and Bristol 2018-2021',fontsize = 20)

plt.xticks(rotation = 50)
plt.grid(b=None)
plt.show()

# %%
# graph of last outcome of reported crimes against time

plt.style.use('dark_background')
m = other_cities.groupby(['month', 'last outcome category']).size().unstack().plot.line(figsize=(15, 10))
plt.title('Last Outcome Category Against Time',fontsize = 20)
plt.grid(b=None)
m.legend(loc=(1.1,0))

# %%
# graph of crime types against time

m = other_cities.groupby(['month', 'crime type']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=None)

plt.title('Crime Type Against Time',fontsize = 20)

m.legend(loc=(1.04,0.5))

# %%
# graphs of crimes reported and received by which police force

fig, axs = plt.subplots(1, 2, figsize=(20,10))
sns.countplot(y='crime type', data=other_cities, order=other_cities['crime type'].value_counts().index, ax=axs[0])
m = sns.countplot(x='reported by', hue='crime type', data=other_cities, order = other_cities['reported by'].value_counts().index, ax=axs[1] )
m.legend(loc=(1.04,0.5))
plt.show()

# %%
# display top 10 crime count for Leeds, Bradford, Liverpool, Sheffield and Bristol for years 2018-2021

other_cities['crime type'].value_counts().head(10)
# Out:
# Violence and sexual offences    463991
# Public order                    139385
# Criminal damage and arson       129031
# Other theft                      94682
# Vehicle crime                    92373
# Burglary                         91292
# Shoplifting                      70628
# Drugs                            49485
# Other crime                      28174
# Theft from the person            18043
# Name: crime type, dtype: int64

# %%
# bubble visualisation for top street crimes reported

other_cities = {
    'crime_type': ['Violence and sexual offences', 'Public order', 'Criminal damage and arson', 'Other theft', 'Vehicle crime', 'Burglary', 'Shoplifting', 'Drugs', 'Other crime', 'Theft from the person'],
    'crime_numbers': [463991, 139385, 129031, 94682, 92373, 91292, 70628, 49485, 28174, 18043],
    'color': ['#E74C3C', '#884EA0', '#2471A3', '#17A589', '#D4AC0D', '#95A5A6', '#F1948A', '#A9CCE3', '#F0B27A', '#7DCEA0']
}

class crime_chart:
    def __init__(self, area, bubble_spacing=0):
        """
        Setup for bubble collapse.

        Parameters
        ----------
        area : array-like
            Area of the bubbles.
        bubble_spacing : float, default: 0
            Minimal spacing between bubbles after collapsing.

        """
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # calculate initial grid layout for bubbles
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        idx_min = np.argmin(distance)
        return idx_min if type(idx_min) == np.ndarray else [idx_min]

    def collapse(self, n_iterations=50):
        """
        Move bubbles to the center of mass.

        Parameters
        ----------
        n_iterations : int, default: 50
            Number of moves to perform.
        """
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                # try to move directly towards the center of mass
                # direction vector from bubble to the center of mass
                dir_vec = self.com - self.bubbles[i, :2]

                # shorten direction vector to have length of 1
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                # calculate new bubble position
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                # check whether new bubble collides with other bubbles
                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    # try to move around a bubble that you collide with
                    # find colliding bubble
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        # calculate direction vector
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        # calculate orthogonal vector
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        # test which direction to go
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        """
        Draw the bubble plot.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
        labels : list
            Labels of the bubbles.
        colors : list
            Colors of the bubbles.
        """
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center')


chart = crime_chart(area=other_cities['crime_numbers'],
                           bubble_spacing=1.0)

chart.collapse()

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
chart.plot(
    ax, other_cities['crime_type'], other_cities['color'])
ax.axis("off")
ax.relim()
ax.autoscale_view()
ax.set_title('Top Street Crimes in Leeds, Liverpool, Sheffield, Bradford & Bristol 2018-2021')

plt.show();

# %%
# display top 10 crime locations

other_cities = pd.read_csv('C:/Users/User/other_cities_df.csv')
other_cities['location'].value_counts().head(10)
# Out:
# On or near Supermarket                            35789
# On or near Parking Area                           26276
# On or near Shopping Area                          25405
# On or near Petrol Station                         17042
# On or near Sports/Recreation Area                 14901
# On or near Pedestrian Subway                      12324
# On or near Nightclub                              11707
# On or near Hospital                                8256
# On or near Further/Higher Educational Building     3996
# On or near Park/Open Space                         3401
# Name: location, dtype: int64

# %%
# bubble visualisation for top street crime locations 

other_cities = {
    'crime_loc': ['On or near Supermarket', 'On or near Parking Area', 'On or near Shopping Area', 'On or near Petrol Station', 'On or near Sports/Recreation Area', 'On or near Pedestrian Subway', 'On or near Nightclub', 'On or near Hospital', 'On or near Further/Higher Educational Building', 'On or near Park/Open Space'],
    'crime_loc_num': [35789, 26276, 25405, 17042, 14901, 12324, 11707, 8256, 3996, 3401],
    'color': ['#E74C3C', '#884EA0', '#2471A3', '#17A589', '#D4AC0D', '#95A5A6', '#F1948A', '#A9CCE3', '#F0B27A', '#7DCEA0']
}

class crime_chart:
    def __init__(self, area, bubble_spacing=0):

        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # calculate initial grid layout for bubbles
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        idx_min = np.argmin(distance)
        return idx_min if type(idx_min) == np.ndarray else [idx_min]

    def collapse(self, n_iterations=50):

        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                # try to move directly towards the center of mass
                # direction vector from bubble to the center of mass
                dir_vec = self.com - self.bubbles[i, :2]

                # shorten direction vector to have length of 1
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                # calculate new bubble position
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                # check whether new bubble collides with other bubbles
                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    # try to move around a bubble that you collide with
                    # find colliding bubble
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        # calculate direction vector
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        # calculate orthogonal vector
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        # test which direction to go
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
 
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center')


chart = crime_chart(area=other_cities['crime_loc_num'],
                           bubble_spacing=1.0)

chart.collapse()

fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
chart.plot(
    ax, other_cities['crime_loc'], other_cities['color'])
ax.axis("off")
ax.relim()
ax.autoscale_view()
ax.set_title('Top Street Crime Spots in Leeds, Liverpool, Sheffield, Bradford & Bristol 2018-2021')

plt.show();

# %%
# display street crimes received by which police force from 2018-2021

other_cities = pd.read_csv('C:/Users/User/other_cities_df.csv')

plt.rcParams['figure.figsize'] = (20, 10)
plt.style.use('dark_background')

sns.countplot(other_cities['reported by'], palette = 'gnuplot')

plt.title('Reports of Street Crimes Received from 2018-2021', fontweight = 30, fontsize = 20)
plt.xticks(rotation = 45)
#plt.grid(False)
plt.show();

# %%
# combined monthly street crimes reported for 2018-2021

other_cities['month'] = pd.to_datetime(other_cities['month'])

other_cities['month '] = other_cities['month'].dt.month

#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (15, 8)

sns.countplot(other_cities['month '], palette = 'autumn',)
plt.title('Combined Monthly Street Crimes Reported for Years 2018-2021', fontsize = 20)

plt.show()

# %%
# display street crimes reported for years 2018-2021

other_cities['month'] = pd.to_datetime(other_cities['month'])

other_cities['year '] = other_cities['month'].dt.year

#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (15, 8)

sns.countplot(other_cities['year '], palette = 'cool',)
plt.title('Street Crimes Reported for Years 2018-2021', fontsize = 20)

plt.show()

# %%
# display types of crime reported per year

plt.rcParams['figure.figsize'] = (20, 9)
plt.style.use('dark_background')

sns.countplot(other_cities['crime type'], hue=other_cities['year '], palette = 'viridis')

plt.title('Street Crimes in Leeds, Bradford, Liverpool, Sheffield and Bristol', fontweight = 30, fontsize = 20)
plt.xticks(rotation = 45)
plt.grid(False)
plt.show()

# %% [markdown]
# The yearly graph of crimes reported shows that street crimes decreased from 2018 to 2021 with the exception of Violence and sexual offences, Drugs, Other crime, and Public order in which all four have a slight increase in year 2020. All four crime types have decreased in 2021 along with all other crimes.

# %%
# display crimes reported for each month per year

other_cities['month'] = pd.to_datetime(other_cities['month'])

other_cities['month '] = other_cities['month'].dt.month

#plt.style.use('fivethirtyeight')
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (15, 8)

sns.countplot(other_cities['month '], hue=other_cities['year '], palette = 'magma')
plt.title('Monthly Street Crimes Reported in Leeds, Bradford, Liverpool, Sheffield and Bristol', fontsize = 20)

plt.show();

# %%
# display last rows of data

other_cities.tail()
# Out:
#              month                     reported by  longitude   latitude  \
# 1220530 2021-09-01  Avon and Somerset Constabulary  -2.560748  51.472315
# 1220531 2021-09-01  Avon and Somerset Constabulary  -2.560484  51.473152
# 1220532 2021-09-01  Avon and Somerset Constabulary  -2.559442  51.472717
# 1220533 2021-09-01  Avon and Somerset Constabulary  -2.560748  51.472315
# 1220534 2021-09-01  Avon and Somerset Constabulary  -2.559340  51.471396
#
#                            location  lsoa code lsoa name  \
# 1220530        On or near Glen Park    1014574   Bristol
# 1220531  On or near Chisbury Street    1014574   Bristol
# 1220532    On or near Apsley Street    1014574   Bristol
# 1220533        On or near Glen Park    1014574   Bristol
# 1220534    On or near Juniper Court    1014574   Bristol
#
#                            crime type  \
# 1220530  Violence and sexual offences
# 1220531  Violence and sexual offences
# 1220532  Violence and sexual offences
# 1220533  Violence and sexual offences
# 1220534  Violence and sexual offences
#
#                               last outcome category  covid     date  \
# 1220530                         Under investigation      1  2021-09
# 1220531                         Under investigation      1  2021-09
# 1220532                 Unable to prosecute suspect      1  2021-09
# 1220533  Action to be taken by another organisation      1  2021-09
# 1220534                 Unable to prosecute suspect      1  2021-09
#
#          stringency  month   year
# 1220530      42.034       9   2021
# 1220531      42.034       9   2021
# 1220532      42.034       9   2021
# 1220533      42.034       9   2021
# 1220534      42.034       9   2021

# %%
plt.rcParams['figure.figsize'] = (10, 9)
plt.style.use('seaborn')
sns.boxplot(data=other_cities['stringency'], orient="h")
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10, 9)
plt.style.use('seaborn')
sns.histplot(data=other_cities['stringency'])
plt.show()

# %% [markdown]
# # Plotting Pre-Pandemic Data

# %%
other_no_s = other_cities[other_cities['stringency'] == 0.0]
other_no_s.head()
# Out:
#        month            reported by  longitude   latitude  \
# 0 2018-01-01  West Yorkshire Police  -1.388671  53.935321
# 1 2018-01-01  West Yorkshire Police  -1.391328  53.938003
# 2 2018-01-01  West Yorkshire Police  -1.388828  53.936031
# 3 2018-01-01  West Yorkshire Police  -1.391328  53.938003
# 4 2018-01-01  West Yorkshire Police  -1.389567  53.938615
#
#                      location  lsoa code lsoa name  \
# 0     On or near Coxwold View    1011698     Leeds
# 1      On or near Supermarket    1011698     Leeds
# 2     On or near Coxwold Hill    1011698     Leeds
# 3      On or near Supermarket    1011698     Leeds
# 4  On or near Ainsty Crescent    1011698     Leeds
#
#                      crime type  \
# 0     Criminal damage and arson
# 1                   Shoplifting
# 2                 Vehicle crime
# 3  Violence and sexual offences
# 4  Violence and sexual offences
#
#                            last outcome category  covid     date  stringency  \
# 0  Investigation complete; no suspect identified      0  2018-01         0.0
# 1  Investigation complete; no suspect identified      0  2018-01         0.0
# 2  Investigation complete; no suspect identified      0  2018-01         0.0
# 3                    Unable to prosecute suspect      0  2018-01         0.0
# 4              Offender given community sentence      0  2018-01         0.0
#
#    month   year
# 0       1   2018
# 1       1   2018
# 2       1   2018
# 3       1   2018
# 4       1   2018

# %%
# display graph of crimes against time

plt.style.use('dark_background')
m = other_no_s.groupby(['month', 'crime type']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=None)
plt.title('Street Crimes Reported Before Covid-19 Pandemic',fontsize = 20)

m.legend(loc=(1.04,0.5))

# %%
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (15, 8)

sns.countplot(other_no_s['year '], palette = 'cool',)
plt.title('Street Crimes Before Covid-19 Pandemic', fontsize = 20)

plt.show();

# %%
# display crimes reported before the Covid-19 Pandemic

m = other_no_s.groupby(['month ', 'year ']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=None)
plt.style.use('dark_background')
plt.title('Street Crimes Reported Before Covid-19 Pandemic',fontsize = 20)

m.legend(loc=(1.04,0.5))

# %% [markdown]
# # Plotting Pandemic Period Data

# %%
#data with stringency(pandemic period)

other_s = other_cities[other_cities['stringency'] > 0.0]
other_s.head()
# Out:
#             month            reported by  longitude   latitude  \
# 721522 2020-03-01  West Yorkshire Police  -1.387612  53.936897
# 721523 2020-03-01  West Yorkshire Police  -1.389567  53.938615
# 721524 2020-03-01  West Yorkshire Police  -1.389567  53.938615
# 721525 2020-03-01  West Yorkshire Police  -1.390705  53.936850
# 721526 2020-03-01  West Yorkshire Police  -1.396755  53.939828
#
#                             location  lsoa code lsoa name  \
# 721522  On or near North Grove Drive    1011698     Leeds
# 721523    On or near Ainsty Crescent    1011698     Leeds
# 721524    On or near Ainsty Crescent    1011698     Leeds
# 721525        On or near Maple Drive    1011698     Leeds
# 721526         On or near Aire Mount    1011699     Leeds
#
#                           crime type  \
# 721522  Violence and sexual offences
# 721523  Violence and sexual offences
# 721524  Violence and sexual offences
# 721525                   Other crime
# 721526                 Vehicle crime
#
#                                 last outcome category  covid     date  \
# 721522                    Unable to prosecute suspect      1  2020-03
# 721523                    Unable to prosecute suspect      1  2020-03
# 721524                    Unable to prosecute suspect      1  2020-03
# 721525  Investigation complete; no suspect identified      1  2020-03
# 721526  Investigation complete; no suspect identified      1  2020-03
#
#         stringency  month   year
# 721522      37.484       3   2020
# 721523      37.484       3   2020
# 721524      37.484       3   2020
# 721525      37.484       3   2020
# 721526      37.484       3   2020

# %%
plt.rcParams['figure.figsize'] = (10, 9)
plt.grid(b=None)
sns.histplot(data=other_s['stringency'])
plt.show()

# %%
plt.figure(figsize=(20,10))

plt.plot(other_s['month'], other_s['stringency'], label = 'Stringency')

plt.xlabel('Year and Month')
plt.ylabel('stringency')

plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.title('Stringency against time')

plt.show()

# %%
plt.rcParams['figure.figsize'] = (20, 9)
#plt.style.use('seaborn')
plt.style.use('dark_background')

m = other_s.groupby(['stringency', 'crime type']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=True)
plt.title('Crime Type Against Stringency',fontsize = 20)
m.legend(loc=(1.04,0.5))

# %%
plt.style.use('dark_background')
plt.rcParams['figure.figsize'] = (15, 8)

sns.countplot(other_s['year '], palette = 'cool',)
plt.title('Street Crimes Reported During the Covid-19 Pandemic', fontsize = 20)

plt.show()

# %%
# display street crimes reported each month during the Covid-19 Pandemic

plt.rcParams['figure.figsize'] = (20, 9)
#plt.style.use('seaborn')
plt.style.use('dark_background')

m = other_s.groupby(['month ', 'year ']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=True)
plt.title('Street Crimes Reported Each Month During the Covid-19 Pandemic',fontsize = 20)
m.legend(loc=(1.04,0.5))

# %%
# display types of crime reported each month during the Covid-19 Pandemic

m = other_s.groupby(['month', 'crime type']).size().unstack().plot.line(figsize=(15, 10))
plt.grid(b=None)

plt.title('Types Street Crimes Reported Each Month During the Covid-19 Pandemic',fontsize = 20)

m.legend(loc=(1.04,0.5))

# %%
#check different crime types reported

x = other_s['crime type'].value_counts()
y = other_s['crime type'].value_counts().count()

print(x)
print('\n')
print("There are are {} categories ".format(y))
# Out:
# Violence and sexual offences    207219
# Public order                     66645
# Criminal damage and arson        51787
# Other theft                      32034
# Vehicle crime                    30873
# Burglary                         29173
# Drugs                            24339
# Shoplifting                      22986
# Other crime                      12238
# Bicycle theft                     6733
# Robbery                           5658
# Possession of weapons             4674
# Theft from the person             4654
# Name: crime type, dtype: int64
#
#
# There are are 13 categories
